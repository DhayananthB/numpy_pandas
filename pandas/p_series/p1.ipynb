# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# *Series from lists*

# %%
name = ['ab','d','c']

o = pd.Series(name)
o
# Out:
# 0    ab
# 1     d
# 2     c
# dtype: object

# %%
ind = ['I',"II","III"]

pd.Series(name,index=ind,name='Edha nokki poren')
# Out:
# I      ab
# II      d
# III     c
# Name: Edha nokki poren, dtype: object

# %% [markdown]
# *Series from a dictionary*

# %%
d = {
    'I':'ab',
    'II':'cd'
}
new_Series = pd.Series(d, name='meow')

new_Series
# Out:
# I     ab
# II    cd
# Name: meow, dtype: object

# %% [markdown]
# *Series Attributes*

# %%
new_Series.size
# Out:
# 2

# %%
print(new_Series.dtype)
# Out:
# object

# %%
new_Series.name
# Out:
# 'meow'

# %%
print(o.name)
# Out:
# None

# %%
o.is_unique
# Out:
# True

# %%
o.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
new_Series.index
# Out:
# Index(['I', 'II'], dtype='object')

# %%
new_Series.values
# Out:
# array(['ab', 'cd'], dtype=object)

# %% [markdown]
# *Series using read_csv*

# %%
subs = pd.read_csv('subs.csv').squeeze()

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
# help(pd.read_csv)

# %% [markdown]
# with two columns

# %%
vk = pd.read_csv('kohli_ipl.csv',index_col='match_no').squeeze()

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('bollywood.csv',index_col='movie').squeeze()

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ##### Series methods

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.index
# Out:
# RangeIndex(start=0, stop=365, step=1)

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
type(movies.index)
# Out:
# pandas.core.indexes.base.Index

# %%
vk.tail(3)
# Out:
# match_no
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
vk.sample(4)
# Out:
# match_no
# 97     67
# 66      9
# 136    10
# 77      1
# Name: runs, dtype: int64

# %%
print(movies.value_counts())
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values()
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# *Series maths methods*

# %%
vk.size
# Out:
# 215

# %%
vk.count()
# Out:
# 215

# %%
subs.sum()
# Out:
# 49510

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
vk.median()
# Out:
# 24.0

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
subs.max()
# Out:
# 396

# %% [markdown]
# *Series Indexing*

# %%
x = pd.Series([81,48,61,530,6])

# %%
n=np.array([[1,2,3,4,5],[11,23,45,56,78]])
print(n[-1,-1])
# Out:
# 78

# %%
x[1]
# Out:
# 48

# %%
# x[-1] - error

# %%
vk[5:8]
# Out:
# match_no
# 6     9
# 7    34
# 8     0
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
vk[[2,4,5]]
# Out:
# match_no
# 2    23
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk[::25]
# Out:
# match_no
# 1        1
# 26       2
# 51      31
# 76      11
# 101     41
# 126    109
# 151     39
# 176     43
# 201     12
# Name: runs, dtype: int64

# %%
movies['3 Storeys']
# Out:
# 'Aisha Ahmed'

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[1]=99

# %%
vk
# Out:
# match_no
# 1      99
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#adding a new row
vk[0] = 0

# %%
vk
# Out:
# match_no
# 1      99
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 212    20
# 213    73
# 214    25
# 215     7
# 0       0
# Name: runs, Length: 216, dtype: int64

# %%
vk[1:3]=[100,100]

# %%
vk
# Out:
# match_no
# 1       99
# 2      100
# 3      100
# 4       12
# 5        1
#       ...
# 212     20
# 213     73
# 214     25
# 215      7
# 0        0
# Name: runs, Length: 216, dtype: int64

# %%
vk[[1,2,7]]=[100,100,90]

# %%
list(vk)[:20]
# Out:
# [100, 100, 100, 12, 1, 9, 90, 0, 21, 3, 10, 38, 3, 11, 50, 2, 22, 19, 16, 15]

# %%
d = dict(vk)

# %%
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
subs = np.array([1,2,3,4])

print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 4
# <class 'numpy.ndarray'>
# ...

# %%
3 in subs
# Out:
# True

# %%
'2 States (2014 film)' in movies
# Out:
# True

# %%
for i in movies:
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
subs = pd.Series(subs)
subs
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
100 + subs
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# dtype: int32

# %%
subs > 3
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# *Boolean indexing on Series*

# %%
vk[vk==0].size
# Out:
# 10

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import sys

a = 5
n = np.array([5],dtype=np.int16)
sys.getsizeof(a)
sys.getsizeof(n)
# Out:
# 114

# %% [markdown]
# ### important series methods

# %%
# astype

vk.astype('int16')
# Out:
# match_no
# 1      100
# 2      100
# 3      100
# 4       12
# 5        1
#       ...
# 212     20
# 213     73
# 214     25
# 215      7
# 0        0
# Name: runs, Length: 216, dtype: int16

# %%
#between 

vk[vk.between(51,99)].size
# Out:
# 44

# %%
subs = pd.read_csv('subs.csv').squeeze()

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
temp = pd.Series([1,1,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    3
# 4    3
# 5    4
# 6    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# 3

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 3    3
# 5    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# 7

# %%
  temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(987)
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3    987.0
# 4      5.0
# 5      6.0
# 6    987.0
# 7      8.0
# 8    987.0
# 9     10.0
# dtype: float64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1      100
# 2      100
# 3      100
# 4       12
# 5        1
#       ...
# 212     20
# 213     73
# 214     25
# 215      7
# 0        0
# Name: runs, Length: 216, dtype: int64

# %%
vk.apply(lambda x:x-1)
# Out:
# match_no
# 1      99
# 2      99
# 3      99
# 4      11
# 5       0
#        ..
# 212    19
# 213    72
# 214    24
# 215     6
# 0      -1
# Name: runs, Length: 216, dtype: int64

# %%
vk = vk.copy()
